# %%
import pathlib

import joblib
import numpy as np
import pandas as pd
import pycytominer

# %%
model_file_dir = pathlib.Path(
    "../models/multi_regression_model_ntrees_1000.joblib"
).resolve()
shuffled_model_file_dir = pathlib.Path(
    "../models/shuffled_multi_regression_model_ntrees_1000.joblib"
).resolve()
train_test_wells_path = pathlib.Path(
    "../data_splits/train_test_wells.parquet"
).resolve()

predictions_save_path = pathlib.Path(
    "../results/predicted_terminal_profiles_from_all_time_points.parquet"
).resolve()

profile_data_path = pathlib.Path(
    "../../data/CP_scDINO_features/combined_CP_scDINO_norm_fs_aggregated.parquet"
).resolve()
terminal_column_names = pathlib.Path("../results/terminal_columns.txt").resolve(
    strict=True
)
terminal_column_names = [
    line.strip() for line in terminal_column_names.read_text().splitlines()
]

data_split_df = pd.read_parquet(train_test_wells_path)
df = pd.read_parquet(profile_data_path)
metadata_cols = [cols for cols in df.columns if "Metadata" in cols]
features_cols = [cols for cols in df.columns if "Metadata" not in cols]
features_cols = features_cols
aggregate_df = pycytominer.aggregate(
    population_df=df,
    strata=["Metadata_Well", "Metadata_Time"],
    features=features_cols,
    operation="median",
)


metadata_df = df[metadata_cols]
metadata_df = metadata_df.drop_duplicates(subset=["Metadata_Well", "Metadata_Time"])
metadata_df = metadata_df.reset_index(drop=True)
aggregate_df = pd.merge(
    metadata_df, aggregate_df, on=["Metadata_Well", "Metadata_Time"]
)
print(aggregate_df.shape)
aggregate_df.head()
# Out:
# (390, 2373)
#   Metadata_Well Metadata_Time  Metadata_plate  Metadata_number_of_singlecells  \
# 0          C-02           0.0               1                             180
# 1          C-02           1.0               1                             178
# 2          C-02          10.0               1                             180
# 3          C-02          11.0               1                             179
# 4          C-02          12.0               1                             180
#
#   Metadata_compound Metadata_dose Metadata_control Metadata_ImageNumber  \
# 0     Staurosporine           0.0         negative                    1
# 1     Staurosporine           0.0         negative                    2
# 2     Staurosporine           0.0         negative                   11
# 3     Staurosporine           0.0         negative                   12
# 4     Staurosporine           0.0         negative                   13
#
#   Metadata_FOV  Metadata_Cells_Number_Object_Number  ...  \
# 0         0001                                  101  ...
# 1         0001                                  104  ...
# 2         0001                                   10  ...
# 3         0001                                   13  ...
# 4         0001                                   10  ...
#
#    channel_DNA_cls_feature_91_scDINO  channel_DNA_cls_feature_92_scDINO  \
# 0                           0.208938                          -0.073630
# 1                          -0.080875                           0.047516
# 2                          -0.104633                           0.049896
# 3                          -0.087787                          -0.101442
# 4                           0.009973                          -0.036503
#
#    channel_DNA_cls_feature_93_scDINO  channel_DNA_cls_feature_94_scDINO  \
# 0                           0.008897                          -0.055376
# 1                          -0.007985                           0.057872
# 2                           0.155820                           0.073132
# 3                           0.275884                           0.209213
# 4                           0.473306                           0.311591
#
#    channel_DNA_cls_feature_95_scDINO channel_DNA_cls_feature_96_scDINO  \
# 0                           0.131249                         -0.053869
# 1                          -0.307675                          0.226858
# 2                          -0.514341                          0.125680
# 3                          -0.459635                          0.113541
# 4                          -0.641266                          0.173728
#
#   channel_DNA_cls_feature_97_scDINO channel_DNA_cls_feature_98_scDINO  \
# 0                          0.121860                          0.006765
# 1                         -0.097667                          0.154435
# 2                          0.012130                          0.206564
# 3                         -0.091702                          0.251352
# 4                          0.024222                          0.272495
#
#   channel_DNA_cls_feature_99_scDINO channel_DNA_cls_feature_9_scDINO
# 0                         -0.151495                         0.121353
# 1                          0.009346                        -0.100267
# 2                         -0.001114                        -0.069553
# 3                          0.081938                        -0.135812
# 4                          0.057495                        -0.097702
#
# [5 rows x 2373 columns]

# %%
# map the train/test wells to the aggregate data
aggregate_df["Metadata_data_split"] = aggregate_df["Metadata_Well"].map(
    data_split_df.set_index("Metadata_Well")["data_split"]
)
data_split = aggregate_df.pop("Metadata_data_split")
aggregate_df.insert(0, "Metadata_data_split", data_split)
aggregate_df["Metadata_Time"] = aggregate_df["Metadata_Time"].astype(float)
aggregate_df["Metadata_data_split"].unique()
# Out:
# array(['test', 'train'], dtype=object)

# %%
aggregate_df.head(15)
# Out:
#    Metadata_data_split Metadata_Well  Metadata_Time  Metadata_plate  \
# 0                 test          C-02            0.0               1
# 1                 test          C-02            1.0               1
# 2                 test          C-02           10.0               1
# 3                 test          C-02           11.0               1
# 4                 test          C-02           12.0               1
# 5                 test          C-02            2.0               1
# 6                 test          C-02            3.0               1
# 7                 test          C-02            4.0               1
# 8                 test          C-02            5.0               1
# 9                 test          C-02            6.0               1
# 10                test          C-02            7.0               1
# 11                test          C-02            8.0               1
# 12                test          C-02            9.0               1
# 13               train          C-03            0.0               1
# 14               train          C-03            1.0               1
#
#     Metadata_number_of_singlecells Metadata_compound Metadata_dose  \
# 0                              180     Staurosporine           0.0
# 1                              178     Staurosporine           0.0
# 2                              180     Staurosporine           0.0
# 3                              179     Staurosporine           0.0
# 4                              180     Staurosporine           0.0
# 5                              176     Staurosporine           0.0
# 6                              175     Staurosporine           0.0
# 7                              174     Staurosporine           0.0
# 8                              174     Staurosporine           0.0
# 9                              175     Staurosporine           0.0
# 10                             176     Staurosporine           0.0
# 11                             181     Staurosporine           0.0
# 12                             181     Staurosporine           0.0
# 13                             185     Staurosporine          0.61
# 14                             183     Staurosporine          0.61
#
#    Metadata_control Metadata_ImageNumber Metadata_FOV  ...  \
# 0          negative                    1         0001  ...
# 1          negative                    2         0001  ...
# 2          negative                   11         0001  ...
# 3          negative                   12         0001  ...
# 4          negative                   13         0001  ...
# 5          negative                    3         0001  ...
# 6          negative                    4         0001  ...
# 7          negative                    5         0001  ...
# 8          negative                    6         0001  ...
# 9          negative                    7         0001  ...
# 10         negative                    8         0001  ...
# 11         negative                    9         0001  ...
# 12         negative                   10         0001  ...
# 13             test                    1         0001  ...
# 14             test                    2         0001  ...
#
#     channel_DNA_cls_feature_91_scDINO  channel_DNA_cls_feature_92_scDINO  \
# 0                            0.208938                          -0.073630
# 1                           -0.080875                           0.047516
# 2                           -0.104633                           0.049896
# 3                           -0.087787                          -0.101442
# 4                            0.009973                          -0.036503
# 5                           -0.018410                           0.015301
# 6                           -0.030772                          -0.005703
# 7                           -0.045352                           0.037487
# 8                           -0.108421                          -0.002040
# 9                           -0.077427                           0.062856
# 10                          -0.154970                          -0.073000
# 11                          -0.126063                          -0.118128
# 12                          -0.007663                           0.018305
# 13                          -0.054444                          -0.072249
# 14                          -0.055074                          -0.137701
#
#     channel_DNA_cls_feature_93_scDINO  channel_DNA_cls_feature_94_scDINO  \
# 0                            0.008897                          -0.055376
# 1                           -0.007985                           0.057872
# 2                            0.155820                           0.073132
# 3                            0.275884                           0.209213
# 4                            0.473306                           0.311591
# 5                            0.113410                           0.051032
# 6                            0.111358                           0.015614
# 7                            0.029287                          -0.053088
# 8                            0.020643                           0.026117
# 9                            0.183800                          -0.042906
# 10                           0.155917                           0.139415
# 11                           0.191041                           0.144592
# 12                           0.266398                           0.140102
# 13                           0.230814                           0.067691
# 14                           0.101771                           0.004644
#
#     channel_DNA_cls_feature_95_scDINO  channel_DNA_cls_feature_96_scDINO  \
# 0                            0.131249                          -0.053869
# 1                           -0.307675                           0.226858
# 2                           -0.514341                           0.125680
# 3                           -0.459635                           0.113541
# 4                           -0.641266                           0.173728
# 5                           -0.281085                           0.129891
# 6                           -0.305060                           0.172338
# 7                           -0.378882                           0.200138
# 8                           -0.411899                           0.219469
# 9                           -0.389280                           0.131029
# 10                          -0.290757                           0.008507
# 11                          -0.295870                           0.097225
# 12                          -0.482241                           0.084170
# 13                           0.129544                           0.152350
# 14                          -0.210968                           0.273543
#
#    channel_DNA_cls_feature_97_scDINO channel_DNA_cls_feature_98_scDINO  \
# 0                           0.121860                          0.006765
# 1                          -0.097667                          0.154435
# 2                           0.012130                          0.206564
# 3                          -0.091702                          0.251352
# 4                           0.024222                          0.272495
# 5                          -0.077894                          0.073283
# 6                           0.021422                          0.147393
# 7                          -0.196770                          0.148845
# 8                          -0.043483                          0.195249
# 9                          -0.051551                          0.136840
# 10                         -0.069841                          0.220221
# 11                          0.019038                          0.243588
# 12                          0.043931                          0.210614
# 13                         -0.039615                          0.181538
# 14                          0.038896                          0.061688
#
#    channel_DNA_cls_feature_99_scDINO channel_DNA_cls_feature_9_scDINO
# 0                          -0.151495                         0.121353
# 1                           0.009346                        -0.100267
# 2                          -0.001114                        -0.069553
# 3                           0.081938                        -0.135812
# 4                           0.057495                        -0.097702
# 5                          -0.030785                        -0.088513
# 6                          -0.012494                        -0.138317
# 7                           0.015237                        -0.109499
# 8                           0.061166                        -0.063724
# 9                           0.066420                        -0.073412
# 10                          0.033844                        -0.067445
# 11                         -0.046458                        -0.077488
# 12                         -0.040368                        -0.061207
# 13                          0.220054                        -0.132296
# 14                         -0.078441                        -0.045642
#
# [15 rows x 2374 columns]

# %%
# if the data_split is train and the time is not 12 then set to non_trained_pair
aggregate_df["Metadata_data_split"] = aggregate_df.apply(
    lambda x: (
        "non_trained_pair"
        if (x["Metadata_data_split"] == "train" and x["Metadata_Time"] != 12.0)
        else x["Metadata_data_split"]
    ),
    axis=1,
)

# %%
# load the model
model = joblib.load(model_file_dir)

metadata_columns = [x for x in aggregate_df.columns if "Metadata_" in x]
# remove metadata columns
features = aggregate_df.drop(columns=metadata_columns)
metadata_df = aggregate_df[metadata_columns]
# predict the terminal feature space
predictions = model.predict(features)
predictions_df = pd.DataFrame(predictions, columns=terminal_column_names)
# insert the metadata columns
for col in metadata_columns:
    predictions_df.insert(0, col, metadata_df[col])
predictions_df["shuffled"] = False

# %%
# load the model
shuffled_model = joblib.load(shuffled_model_file_dir)

metadata_columns = [x for x in aggregate_df.columns if "Metadata_" in x]
shuffled_profile_df = aggregate_df.copy()
for col in shuffled_profile_df.columns:
    shuffled_profile_df[col] = np.random.permutation(shuffled_profile_df[col])
# remove metadata columns
features = shuffled_profile_df.drop(columns=metadata_columns)
metadata_df = aggregate_df[metadata_columns]


# predict the terminal feature space
predictions = shuffled_model.predict(features)
shuffled_predictions_df = pd.DataFrame(predictions, columns=terminal_column_names)
# insert the metadata columns
for col in metadata_columns:
    shuffled_predictions_df.insert(0, col, metadata_df[col])
shuffled_predictions_df["shuffled"] = True

# %%
final_predictions_df = pd.concat([predictions_df, shuffled_predictions_df], axis=0)
# save the predictions
final_predictions_df.to_parquet(predictions_save_path, index=False)
final_predictions_df.head()
# Out:
#                                    Metadata_image_path  Metadata_distance  \
# 0    ../0.pre-process_images/data/processed_images/...           0.303702
# 1    ../0.pre-process_images/data/processed_images/...           0.333772
# 2    ../0.pre-process_images/data/processed_images/...           0.183682
# 3    ../0.pre-process_images/data/processed_images/...           0.528709
# 4    ../0.pre-process_images/data/processed_images/...           0.539604
# ..                                                 ...                ...
# 385  ../0.pre-process_images/data/processed_images/...           0.464124
# 386  ../0.pre-process_images/data/processed_images/...           0.278904
# 387  ../0.pre-process_images/data/processed_images/...           0.356816
# 388  ../0.pre-process_images/data/processed_images/...           0.334816
# 389  ../0.pre-process_images/data/processed_images/...           0.565704
#
#     Metadata_coordinates_y  Metadata_parent_id  Metadata_parent_track_id  \
# 0         [1583.0, 1079.0]                -1.0                        -1
# 1          [882.0, 1105.0]                -1.0                        -1
# 2           [1523.0, 59.0]          10000005.0                        -1
# 3            [372.0, 88.0]          11000013.0                        -1
# 4            [374.0, 76.0]          12000009.0                        -1
# ..                     ...                 ...                       ...
# 385        [430.0, 1647.0]           5000112.0                        -1
# 386          [94.0, 100.0]           6000007.0                        -1
# 387          [656.0, 82.0]           7000009.0                        -1
# 388        [1692.0, 108.0]           8000008.0                        -1
# 389        [1441.0, 137.0]           9000014.0                         8
#
#      Metadata_id  Metadata_x  Metadata_y  Metadata_t  Metadata_track_id  ...  \
# 0      1000096.0      1583.0      1079.0         0.0                 17  ...
# 1      2000099.0       882.0      1105.0         1.0                 99  ...
# 2     11000009.0      1523.0        59.0        10.0                  2  ...
# 3     12000009.0       372.0        88.0        11.0                165  ...
# 4     13000008.0       374.0        76.0        12.0                165  ...
# ..           ...         ...         ...         ...                ...  ...
# 385    6000099.0       430.0      1647.0         5.0                 97  ...
# 386    7000010.0        94.0       100.0         6.0                  4  ...
# 387    8000010.0       656.0        82.0         7.0                132  ...
# 388    9000011.0      1692.0       108.0         8.0                  2  ...
# 389   10000010.0      1441.0       137.0         9.0                  9  ...
#
#     Terminal_Intensity_MADIntensity_DNA  \
# 0                          8.010986e-07
# 1                          5.493248e-07
# 2                          7.019150e-07
# 3                          6.027314e-07
# 4                          5.722133e-07
# ..                                  ...
# 385                        6.256199e-07
# 386                        7.019150e-07
# 387                        5.569543e-07
# 388                        6.485084e-07
# 389                        7.705806e-07
#
#      Terminal_Intensity_MaxIntensity_AnnexinV  \
# 0                                   -0.451732
# 1                                   -0.418905
# 2                                   -0.450462
# 3                                   -0.454100
# 4                                   -0.464113
# ..                                        ...
# 385                                 -0.493885
# 386                                 -0.552781
# 387                                 -0.512264
# 388                                 -0.511236
# 389                                 -0.481171
#
#      Terminal_Intensity_MaxIntensity_DNA  \
# 0                               0.094681
# 1                               0.180874
# 2                               0.162781
# 3                               0.146417
# 4                               0.255976
# ..                                   ...
# 385                             0.407321
# 386                             0.400784
# 387                             0.369352
# 388                             0.325931
# 389                             0.342628
#
#     Terminal_Intensity_MeanIntensity_AnnexinV  \
# 0                                    0.544503
# 1                                    0.010006
# 2                                   -0.080458
# 3                                   -0.190411
# 4                                   -0.129145
# ..                                        ...
# 385                                  0.569581
# 386                                  0.531844
# 387                                  0.453114
# 388                                  0.531222
# 389                                  0.751294
#
#     Terminal_Intensity_MeanIntensity_DNA  \
# 0                               0.581019
# 1                               0.356017
# 2                               0.306073
# 3                               0.305931
# 4                               0.113562
# ..                                   ...
# 385                             0.686251
# 386                             0.588929
# 387                             0.740887
# 388                             0.811340
# 389                             0.820109
#
#     Terminal_Intensity_StdIntensity_AnnexinV  \
# 0                                   0.299668
# 1                                   0.153830
# 2                                  -0.254199
# 3                                  -0.342674
# 4                                  -0.488816
# ..                                       ...
# 385                                 0.525096
# 386                                 0.294714
# 387                                 0.379367
# 388                                 0.414658
# 389                                 0.434039
#
#     Terminal_Intensity_StdIntensity_DNA  \
# 0                              1.180284
# 1                              0.664223
# 2                              0.384115
# 3                              0.383960
# 4                              0.312721
# ..                                  ...
# 385                            2.394105
# 386                            2.594920
# 387                            2.358737
# 388                            2.127400
# 389                            2.113584
#
#     Terminal_Intensity_UpperQuartileIntensity_AnnexinV  \
# 0                                            -0.100999
# 1                                            -0.304624
# 2                                            -0.513559
# 3                                            -0.638237
# 4                                            -0.282783
# ..                                                 ...
# 385                                          -0.193370
# 386                                           0.008132
# 387                                          -0.116773
# 388                                          -0.050339
# 389                                          -0.029484
#
#     Terminal_Intensity_UpperQuartileIntensity_DNA shuffled
# 0                                       -0.453398    False
# 1                                       -0.322697    False
# 2                                        0.048675    False
# 3                                        0.100054    False
# 4                                        0.112673    False
# ..                                            ...      ...
# 385                                     -0.461511     True
# 386                                     -0.526410     True
# 387                                     -0.578691     True
# 388                                     -0.469623     True
# 389                                     -0.615648     True
#
# [780 rows x 48 columns]
