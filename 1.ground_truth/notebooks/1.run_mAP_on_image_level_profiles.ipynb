# %%
import pathlib

import pandas as pd
from copairs import map
from copairs.matching import assign_reference_index

# %%
endpoint_path = pathlib.Path(
    "../../data/CP_feature_select/endpoint_whole_image/feature_selected_whole_image.parquet"
).resolve(strict=True)

map_results_path = pathlib.Path("../data/0.ground_truth/map.parquet").resolve()
map_results_path.parent.mkdir(parents=True, exist_ok=True)

endpoint_df = pd.read_parquet(endpoint_path)
endpoint_df.head()
# Out:
#    Metadata_plate Metadata_compound  Metadata_dose Metadata_control  \
# 0               1     Staurosporine           1.22             test
# 1               1     Staurosporine           1.22             test
# 2               1     Staurosporine           1.22             test
# 3               1     Staurosporine           1.22             test
# 4               1     Staurosporine          78.13             test
#
#   Metadata_Channel Metadata_FOV Metadata_FileLocation Metadata_Time  \
# 0             None         0004                  None          0014
# 1             None         0002                  None          0014
# 2             None         0003                  None          0014
# 3             None         0001                  None          0014
# 4             None         0004                  None          0014
#
#   Metadata_Well Metadata_Z_slice  ...  \
# 0          C-04             0001  ...
# 1          C-04             0001  ...
# 2          C-04             0001  ...
# 3          C-04             0001  ...
# 4          D-10             0001  ...
#
#    Texture_DifferenceEntropy_AnnexinV_3_00_256  \
# 0                                    -1.110862
# 1                                    -2.003338
# 2                                    -0.601772
# 3                                    -1.984114
# 4                                     4.430621
#
#    Texture_DifferenceEntropy_DNA_3_00_256  \
# 0                                0.606494
# 1                                1.068383
# 2                               -1.718307
# 3                                0.603107
# 4                                0.418727
#
#    Texture_DifferenceVariance_AnnexinV_3_03_256  \
# 0                                      0.884984
# 1                                      1.500758
# 2                                      0.899249
# 3                                      0.349924
# 4                                     -0.579661
#
#    Texture_DifferenceVariance_DNA_3_00_256  \
# 0                                -0.791035
# 1                                -1.526473
# 2                                -1.245227
# 3                                -0.790168
# 4                                -0.731447
#
#    Texture_InfoMeas1_AnnexinV_3_00_256  Texture_InfoMeas1_DNA_3_03_256  \
# 0                            -2.241106                       -0.819993
# 1                            -1.202551                        1.091309
# 2                            -1.165456                        0.598269
# 3                            -2.994923                        1.594837
# 4                            -2.363835                       -7.952185
#
#    Texture_InfoMeas2_AnnexinV_3_03_256  \
# 0                             0.473630
# 1                            -0.650447
# 2                             0.267862
# 3                             0.747283
# 4                             3.768172
#
#    Texture_InverseDifferenceMoment_AnnexinV_3_00_256  \
# 0                                           1.205834
# 1                                           1.964588
# 2                                           0.873253
# 3                                           2.022597
# 4                                          -4.995891
#
#    Texture_SumVariance_DNA_3_03_256  Texture_Variance_AnnexinV_3_02_256
# 0                          1.411462                           -1.206193
# 1                          1.485453                           -2.165498
# 2                         -2.096121                           -0.396190
# 3                          0.757480                           -1.438568
# 4                         12.379506                            2.193259
#
# [5 rows x 31 columns]

# %%
reference_col = "Metadata_reference_index"
df_activity = assign_reference_index(
    endpoint_df,
    "Metadata_dose == 0.0",
    reference_col=reference_col,
    default_value=-1,
)
df_activity.head()
# Out:
#    Metadata_plate Metadata_compound  Metadata_dose Metadata_control  \
# 0               1     Staurosporine           1.22             test
# 1               1     Staurosporine           1.22             test
# 2               1     Staurosporine           1.22             test
# 3               1     Staurosporine           1.22             test
# 4               1     Staurosporine          78.13             test
#
#   Metadata_Channel Metadata_FOV Metadata_FileLocation Metadata_Time  \
# 0             None         0004                  None          0014
# 1             None         0002                  None          0014
# 2             None         0003                  None          0014
# 3             None         0001                  None          0014
# 4             None         0004                  None          0014
#
#   Metadata_Well Metadata_Z_slice  ...  Texture_DifferenceEntropy_DNA_3_00_256  \
# 0          C-04             0001  ...                                0.606494
# 1          C-04             0001  ...                                1.068383
# 2          C-04             0001  ...                               -1.718307
# 3          C-04             0001  ...                                0.603107
# 4          D-10             0001  ...                                0.418727
#
#    Texture_DifferenceVariance_AnnexinV_3_03_256  \
# 0                                      0.884984
# 1                                      1.500758
# 2                                      0.899249
# 3                                      0.349924
# 4                                     -0.579661
#
#    Texture_DifferenceVariance_DNA_3_00_256  \
# 0                                -0.791035
# 1                                -1.526473
# 2                                -1.245227
# 3                                -0.790168
# 4                                -0.731447
#
#    Texture_InfoMeas1_AnnexinV_3_00_256  Texture_InfoMeas1_DNA_3_03_256  \
# 0                            -2.241106                       -0.819993
# 1                            -1.202551                        1.091309
# 2                            -1.165456                        0.598269
# 3                            -2.994923                        1.594837
# 4                            -2.363835                       -7.952185
#
#    Texture_InfoMeas2_AnnexinV_3_03_256  \
# 0                             0.473630
# 1                            -0.650447
# 2                             0.267862
# 3                             0.747283
# 4                             3.768172
#
#    Texture_InverseDifferenceMoment_AnnexinV_3_00_256  \
# 0                                           1.205834
# 1                                           1.964588
# 2                                           0.873253
# 3                                           2.022597
# 4                                          -4.995891
#
#    Texture_SumVariance_DNA_3_03_256  Texture_Variance_AnnexinV_3_02_256  \
# 0                          1.411462                           -1.206193
# 1                          1.485453                           -2.165498
# 2                         -2.096121                           -0.396190
# 3                          0.757480                           -1.438568
# 4                         12.379506                            2.193259
#
#    Metadata_reference_index
# 0                        -1
# 1                        -1
# 2                        -1
# 3                        -1
# 4                        -1
#
# [5 rows x 32 columns]

# %%
pos_sameby = ["Metadata_dose", reference_col]
pos_diffby = []
neg_sameby = []
neg_diffby = ["Metadata_dose", reference_col]
metadata = df_activity.filter(regex="Metadata")
profiles = df_activity.filter(regex="^(?!Metadata)").values

activity_ap = map.average_precision(
    metadata, profiles, pos_sameby, pos_diffby, neg_sameby, neg_diffby
)

activity_ap = activity_ap.query("Metadata_dose != 0.0")
activity_ap.head()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# /home/lippincm/miniforge3/envs/timelapse_analaysis_env/lib/python3.11/site-packages/copairs/compute.py:401: RuntimeWarning: invalid value encountered in divide
#   ap_scores = np.add.reduceat(pr_k * rel_k_list, cutoffs) / num_pos
#    Metadata_plate Metadata_compound  Metadata_dose Metadata_control  \
# 0               1     Staurosporine           1.22             test
# 1               1     Staurosporine           1.22             test
# 2               1     Staurosporine           1.22             test
# 3               1     Staurosporine           1.22             test
# 4               1     Staurosporine          78.13             test
#
#   Metadata_Channel Metadata_FOV Metadata_FileLocation Metadata_Time  \
# 0             None         0004                  None          0014
# 1             None         0002                  None          0014
# 2             None         0003                  None          0014
# 3             None         0001                  None          0014
# 4             None         0004                  None          0014
#
#   Metadata_Well Metadata_Z_slice  Metadata_reference_index  n_pos_pairs  \
# 0          C-04             0001                        -1            7
# 1          C-04             0001                        -1            7
# 2          C-04             0001                        -1            7
# 3          C-04             0001                        -1            7
# 4          D-10             0001                        -1            7
#
#    n_total_pairs  average_precision
# 0             16           0.688240
# 1             16           0.621398
# 2             16           0.579365
# 3             16           0.686508
# 4             16           1.000000

# %%
activity_map = map.mean_average_precision(
    activity_ap, pos_sameby, null_size=1000000, threshold=0.05, seed=0
)
activity_map.reset_index(inplace=True)
activity_map.to_parquet(map_results_path)
activity_map.head()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
#    Metadata_dose  Metadata_reference_index  mean_average_precision  \
# 0           0.61                        -1                0.689292
# 1           1.22                        -1                0.582582
# 2           2.44                        -1                0.506721
# 3           4.88                        -1                0.636422
# 4           9.77                        -1                0.792061
#
#                             indices   p_value  corrected_p_value  below_p  \
# 0  [20, 21, 22, 23, 44, 45, 46, 47]  0.109820           0.197676    False
# 1      [0, 1, 2, 3, 32, 33, 34, 35]  0.304299           0.342336    False
# 2  [24, 25, 26, 27, 52, 53, 54, 55]  0.515194           0.515194    False
# 3  [12, 13, 14, 15, 40, 41, 42, 43]  0.189549           0.243706    False
# 4  [16, 17, 18, 19, 48, 49, 50, 51]  0.026827           0.060361     True
#
#    below_corrected_p
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
