# %%
import pathlib

import pandas as pd

# %%
input_dir = pathlib.Path("../results/mAP_cell_number_subsampled/").resolve(strict=True)
output_file = pathlib.Path("../results/mAP_cell_number_subsampled.parquet").resolve()
# get a list of all files in the directory
df = pd.concat([pd.read_parquet(file) for file in list(input_dir.glob("*"))])
df.to_parquet(output_file)
df.head()
# Out:
#    Metadata_Time  Metadata_dose  Metadata_reference_index  \
# 0            0.0           0.61                        -1
# 1            0.0           1.22                        -1
# 2            0.0           2.44                        -1
# 3            0.0           4.88                        -1
# 4            0.0           9.77                        -1
#
#    mean_average_precision      indices   p_value  corrected_p_value  below_p  \
# 0                0.366667   [0, 9, 18]  0.799431           0.899360    False
# 1                0.438889  [1, 10, 19]  0.699633           0.899360    False
# 2                0.325000  [2, 11, 20]  0.899782           0.899782    False
# 3                0.491667  [3, 12, 21]  0.599176           0.898765    False
# 4                0.525000  [4, 13, 22]  0.499343           0.898765    False
#
#    below_corrected_p  -log10(p-value)  number_of_cells  seed  shuffle
# 0              False         0.046066               75     0     True
# 1              False         0.046066               75     0     True
# 2              False         0.045863               75     0     True
# 3              False         0.046354               75     0     True
# 4              False         0.046354               75     0     True
