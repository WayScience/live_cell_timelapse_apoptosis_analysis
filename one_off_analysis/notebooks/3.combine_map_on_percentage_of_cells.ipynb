# %%
import pathlib

import pandas as pd

# %%
input_dir = pathlib.Path("../results/mAP_cell_percentages/").resolve(strict=True)
output_file = pathlib.Path("../results/mAP_cell_percentages.parquet").resolve()
# get a list of all files in the directory
df = pd.concat([pd.read_parquet(file) for file in list(input_dir.glob("*"))])
df.to_parquet(output_file)
df.head()
# Out:
#    Metadata_Time  Metadata_dose  Metadata_reference_index  \
# 0            0.0           0.61                        -1
# 1            0.0           1.22                        -1
# 2            0.0           2.44                        -1
# 3            0.0           4.88                        -1
# 4            0.0           9.77                        -1
#
#    mean_average_precision      indices       p_value  corrected_p_value  \
# 0                     1.0   [0, 9, 18]  9.999990e-07       9.999990e-07
# 1                     1.0  [1, 10, 19]  9.999990e-07       9.999990e-07
# 2                     1.0  [2, 11, 20]  9.999990e-07       9.999990e-07
# 3                     1.0  [3, 12, 21]  9.999990e-07       9.999990e-07
# 4                     1.0  [4, 13, 22]  9.999990e-07       9.999990e-07
#
#    below_p  below_corrected_p  -log10(p-value)  percentage_of_cells    seed  \
# 0     True               True              6.0                  0.4  246889
# 1     True               True              6.0                  0.4  246889
# 2     True               True              6.0                  0.4  246889
# 3     True               True              6.0                  0.4  246889
# 4     True               True              6.0                  0.4  246889
#
#    shuffle
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
