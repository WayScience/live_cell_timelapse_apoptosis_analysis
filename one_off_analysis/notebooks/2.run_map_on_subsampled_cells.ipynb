# %%
import argparse
import pathlib
import random
import sys

import numpy as np
import pandas as pd

# check if in a jupyter notebook
try:
    cfg = get_ipython().config
    in_notebook = True
except NameError:
    in_notebook = False
import warnings

import pycytominer.aggregate
import tqdm

# Suppress all RuntimeWarnings
warnings.filterwarnings("ignore", category=RuntimeWarning)


sys.path.append("../utils")
from mAP_utils import run_mAP_across_time

# %%
if not in_notebook:
    # setup the argument parser
    parser = argparse.ArgumentParser(
        description="Generate a map for differing cell counts"
    )

    parser.add_argument(
        "--number_of_cells", type=int, help="Seed for the random number generator"
    )
    parser.add_argument(
        "--shuffle", action="store_true", help="Shuffle the order of the wells"
    )
    # parse the arguments
    args = parser.parse_args()
    number_of_cells = args.number_of_cells
    shuffle = args.shuffle
else:
    number_of_cells = 1
    shuffle = False

output_file = pathlib.Path(
    f"../results/mAP_cell_number_subsampled/{number_of_cells}_{shuffle}.parquet"
)
output_file.parent.mkdir(exist_ok=True, parents=True)

# %%
data_file_path = pathlib.Path(
    "../../data/CP_scDINO_features/combined_CP_scDINO_norm_fs.parquet"
).resolve(strict=True)
df = pd.read_parquet(data_file_path)

df.head()
# Out:
#    Metadata_plate Metadata_Well  Metadata_number_of_singlecells  \
# 0               1          C-02                             180
# 1               1          C-02                             180
# 2               1          C-02                             180
# 3               1          C-02                             180
# 4               1          C-02                             180
#
#   Metadata_compound Metadata_dose Metadata_control Metadata_ImageNumber  \
# 0     Staurosporine           0.0         negative                    1
# 1     Staurosporine           0.0         negative                    1
# 2     Staurosporine           0.0         negative                    1
# 3     Staurosporine           0.0         negative                    1
# 4     Staurosporine           0.0         negative                    1
#
#   Metadata_FOV Metadata_Time  Metadata_Cells_Number_Object_Number  ...  \
# 0         0001           0.0                                  101  ...
# 1         0001           0.0                                  111  ...
# 2         0001           0.0                                   11  ...
# 3         0001           0.0                                  128  ...
# 4         0001           0.0                                  132  ...
#
#    channel_DNA_cls_feature_91_scDINO  channel_DNA_cls_feature_92_scDINO  \
# 0                           0.018387                          -0.178214
# 1                          -1.811176                          -0.059895
# 2                          -0.731998                           0.654253
# 3                           1.339222                           1.203907
# 4                          -0.419920                          -0.299610
#
#    channel_DNA_cls_feature_93_scDINO  channel_DNA_cls_feature_94_scDINO  \
# 0                           1.589703                           0.313944
# 1                          -1.208776                           0.102750
# 2                          -0.075728                           0.810937
# 3                           0.509754                          -0.711263
# 4                           0.344723                          -0.251130
#
#    channel_DNA_cls_feature_95_scDINO channel_DNA_cls_feature_96_scDINO  \
# 0                           1.126927                         -0.143103
# 1                           0.845704                          0.083930
# 2                           0.300940                         -0.228780
# 3                           0.067196                         -0.149771
# 4                          -1.851114                          0.669517
#
#   channel_DNA_cls_feature_97_scDINO channel_DNA_cls_feature_98_scDINO  \
# 0                          0.241127                         -0.293259
# 1                         -1.990931                         -0.030848
# 2                          1.782329                          0.153739
# 3                          1.405650                          0.063245
# 4                         -0.439855                          1.576201
#
#   channel_DNA_cls_feature_99_scDINO channel_DNA_cls_feature_9_scDINO
# 0                         -0.283715                         1.434163
# 1                         -1.033722                        -0.942127
# 2                         -0.763335                         0.725093
# 3                          2.162110                         3.187469
# 4                          0.747753                         0.895601
#
# [5 rows x 2373 columns]

# %%
# subset the data by cell count
# one cell per well
subset_df = df.groupby(["Metadata_Well", "Metadata_Time"]).sample(
    n=number_of_cells, random_state=0, replace=False
)

# %%
subset_df.reset_index(drop=True, inplace=True)
if shuffle:
    # permutate the data
    for col in subset_df.columns:
        if col == "Metadata_Time":
            continue
        if col == "Metadata_dose":
            continue
        if col == "Metadata_Well":
            continue
        subset_df[col] = np.random.permutation(subset_df[col])
metadata_cols = [cols for cols in subset_df.columns if "Metadata" in cols]
features_cols = [cols for cols in subset_df.columns if "Metadata" not in cols]
features_cols = features_cols
aggregate_df = pycytominer.aggregate(
    population_df=subset_df,
    strata=["Metadata_Well", "Metadata_Time"],
    features=features_cols,
    operation="median",
)

# %%
metadata_df = subset_df[metadata_cols]
metadata_df = metadata_df.drop_duplicates(subset=["Metadata_Well", "Metadata_Time"])
metadata_df = metadata_df.reset_index(drop=True)
aggregate_df = pd.merge(
    metadata_df, aggregate_df, on=["Metadata_Well", "Metadata_Time"]
)
aggregate_df.head()
# Out:
#    Metadata_plate Metadata_Well  Metadata_number_of_singlecells  \
# 0               1          C-02                             183
# 1               1          C-02                             189
# 2               1          C-02                             180
# 3               1          C-02                             194
# 4               1          C-02                             194
#
#   Metadata_compound Metadata_dose Metadata_control Metadata_ImageNumber  \
# 0     Staurosporine           0.0         negative                    1
# 1     Staurosporine           0.0         negative                    2
# 2     Staurosporine           0.0         negative                   11
# 3     Staurosporine           0.0         negative                   12
# 4     Staurosporine           0.0         negative                   13
#
#   Metadata_FOV Metadata_Time  Metadata_Cells_Number_Object_Number  ...  \
# 0         0002           0.0                                  119  ...
# 1         0002           1.0                                   25  ...
# 2         0001          10.0                                  165  ...
# 3         0002          11.0                                   69  ...
# 4         0002          12.0                                  133  ...
#
#    channel_DNA_cls_feature_91_scDINO  channel_DNA_cls_feature_92_scDINO  \
# 0                           1.538906                          -1.451373
# 1                           0.923269                          -0.754951
# 2                           0.610443                          -0.340604
# 3                          -0.738119                          -0.848537
# 4                          -0.607471                           0.609924
#
#    channel_DNA_cls_feature_93_scDINO  channel_DNA_cls_feature_94_scDINO  \
# 0                           0.689326                           1.015235
# 1                          -0.449772                           1.627492
# 2                           1.409342                          -0.129539
# 3                           0.716184                           0.161059
# 4                          -0.263886                          -0.117806
#
#    channel_DNA_cls_feature_95_scDINO channel_DNA_cls_feature_96_scDINO  \
# 0                          -0.054164                         -1.370754
# 1                           0.648229                         -1.233350
# 2                           0.440814                          0.943133
# 3                          -0.364249                          0.948706
# 4                          -0.393199                          0.352603
#
#   channel_DNA_cls_feature_97_scDINO channel_DNA_cls_feature_98_scDINO  \
# 0                          0.353132                         -0.218096
# 1                          0.019822                         -1.030158
# 2                         -0.095659                         -0.347217
# 3                         -0.091702                         -0.433425
# 4                         -0.019827                          0.286804
#
#   channel_DNA_cls_feature_99_scDINO channel_DNA_cls_feature_9_scDINO
# 0                         -0.669798                        -0.720105
# 1                          0.543025                         0.571881
# 2                         -1.130622                         0.081055
# 3                         -0.820682                         0.999267
# 4                         -0.042885                        -0.230540
#
# [5 rows x 2373 columns]

# %%
dict_of_map_dfs = run_mAP_across_time(
    aggregate_df,
    seed=0,
    time_column="Metadata_Time",
    reference_column_name="Metadata_dose",
    reference_group=aggregate_df["Metadata_dose"].min(),
)


output_df = pd.concat(dict_of_map_dfs.values(), keys=dict_of_map_dfs.keys())
output_df.reset_index(inplace=True)
output_df.rename(columns={"level_0": "Metadata_Time"}, inplace=True)
# add the percentage of cells to the keys
output_df["number_of_cells"] = number_of_cells
output_df["seed"] = 0
output_df["shuffle"] = shuffle
output_df.reset_index(drop=True, inplace=True)
output_df.to_parquet(output_file)
output_df.head()
# Out:
# ---------------------------------------------------------------------------
# UnpairedException                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dict_of_map_dfs = run_mAP_across_time(
#       2     aggregate_df,
#       3     seed=0,
#       4     time_column="Metadata_Time",
#       5     reference_column_name="Metadata_dose",
#       6     reference_group=aggregate_df["Metadata_dose"].min(),
#       7 )
#      10 output_df = pd.concat(dict_of_map_dfs.values(), keys=dict_of_map_dfs.keys())
#      11 output_df.reset_index(inplace=True)
#
# File ~/4TB_A/live_cell_timelapse_apoptosis_analysis/one_off_analysis/notebooks/../utils/mAP_utils.py:65, in run_mAP_across_time(df, seed, time_column, reference_column_name, reference_group)
#      62 metadata = metadata.reset_index(drop=True)
#      63 profiles = profiles.values
# ---> 65 activity_ap = map.average_precision(
#      66     metadata, profiles, pos_sameby, pos_diffby, neg_sameby, neg_diffby
#      67 )
#      69 activity_ap = activity_ap.query(f"{reference_column_name} != {reference_group}")
#      70 activity_map = map.mean_average_precision(
#      71     activity_ap, pos_sameby, null_size=1000000, threshold=0.05, seed=seed
#      72 )
#
# File ~/miniforge3/envs/timelapse_map_env/lib/python3.11/site-packages/copairs/map/average_precision.py:193, in average_precision(meta, feats, pos_sameby, pos_diffby, neg_sameby, neg_diffby, batch_size, distance)
#     191 neg_pairs = find_pairs(meta, sameby=neg_sameby, diffby=neg_diffby)
#     192 if len(neg_pairs) == 0:
# --> 193     raise UnpairedException("Unable to find negative pairs.")
#     195 # Compute similarities for positive pairs
#     196 logger.info("Computing positive similarities...")
#
# UnpairedException: Unable to find negative pairs.
